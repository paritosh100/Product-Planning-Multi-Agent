# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
pip --version
# Out:
# pip 25.2 from c:\Users\Legion\.virtualenvs\multi-ai-agent-deep-9qsefcck\Lib\site-packages\pip (python 3.13)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\legion\.virtualenvs\multi-ai-agent-deep-9qsefcck\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\legion\.virtualenvs\multi-ai-agent-deep-9qsefcck\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\legion\.virtualenvs\multi-ai-agent-deep-9qsefcck\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: edaa4290-bf93-413c-b978-dd16c6dd21fc                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Task: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Website Project Plan**                                                                                       │
# │                                                                                                                 │
# │  **Project Title:** Create a Website for a Small Business                                                       │
# │                                                                                                                 │
# │  **Team Members:**                                                                                              │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Task Breakdown and Timelines                                                                               │
# │                                                                                                                 │
# │  **1. Project Kickoff and Requirements Gathering**                                                              │
# │     - **Description:** Initiate the project with a kickoff meeting to understand detailed project requirements  │
# │  from stakeholders.                                                                                             │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** None                                                                                    │
# │     - **Deliverables:** Project charter, requirements document                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **2. Create Responsive Design**                                                                                │
# │     - **Description:** Design wireframes and mockups that adapt to various screen sizes (desktops, tablets,     │
# │  and mobile). Use tools like Figma or Adobe XD.                                                                 │
# │     - **Timeline:** 2 weeks                                                                                     │
# │     - **Dependencies:** Task 1                                                                                  │
# │     - **Deliverables:** Wireframes, mockups                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **3. Develop User Interface (UI)**                                                                             │
# │     - **Description:** Implement the modern design based on approved mockups. Ensure the interface is visually  │
# │  appealing with a clean layout.                                                                                 │
# │     - **Timeline:** 3 weeks                                                                                     │
# │     - **Dependencies:** Task 2                                                                                  │
# │     - **Deliverables:** Fully coded UI components                                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **4. Create User-Friendly Navigation System**                                                                  │
# │     - **Description:** Build an intuitive navigation structure that allows users to easily find information.    │
# │  Include dropdowns if necessary.                                                                                │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 3                                                                                  │
# │     - **Deliverables:** Functional navigation system                                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **5. Develop “About Us” Page**                                                                                 │
# │     - **Description:** Create a page detailing the company’s history and core values. Collect information from  │
# │  stakeholders for content.                                                                                      │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 3                                                                                  │
# │     - **Deliverables:** “About Us” page                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **6. Create “Services” Page**                                                                                  │
# │     - **Description:** Develop a page that clearly displays the business’s offerings with detailed              │
# │  descriptions.                                                                                                  │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 3                                                                                  │
# │     - **Deliverables:** “Services” page                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **7. Implement “Contact Us” Page**                                                                             │
# │     - **Description:** Design a contact form that integrates with email and includes a map for location.        │
# │  Collect business address and contact details.                                                                  │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 3                                                                                  │
# │     - **Deliverables:** “Contact Us” page                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **8. Develop Blog Section**                                                                                    │
# │     - **Description:** Create a blog section for posting updates and news. Ensure easy-to-use interface for     │
# │  posting content.                                                                                               │
# │     - **Timeline:** 2 weeks                                                                                     │
# │     - **Dependencies:** Task 3                                                                                  │
# │     - **Deliverables:** Blog section                                                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **9. Optimize Performance and SEO**                                                                            │
# │     - **Description:** Enhance site loading speed and implement on-page SEO practices for better visibility on  │
# │  search engines.                                                                                                │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 6, Task 7, Task 8                                                                  │
# │     - **Deliverables:** Performance optimization report                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **10. Integrate Social Media Links**                                                                           │
# │     - **Description:** Add social media buttons and sharing features to the site. Ensure links lead to          │
# │  respective company social profiles.                                                                            │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 8                                                                                  │
# │     - **Deliverables:** Social media integration                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **11. Create Testimonials Section**                                                                            │
# │     - **Description:** Design and implement a section to showcase customer testimonials. Gather testimonials    │
# │  from clients and relevant feedback.                                                                            │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 6                                                                                  │
# │     - **Deliverables:** Testimonials page                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **12. Quality Assurance Testing**                                                                              │
# │     - **Description:** Conduct thorough testing for bugs, usability issues, and ensure responsiveness across    │
# │  devices.                                                                                                       │
# │     - **Timeline:** 2 weeks                                                                                     │
# │     - **Dependencies:** Task 9, Task 10, Task 11                                                                │
# │     - **Deliverables:** QA report, list of identified issues                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **13. Final Review and Launch**                                                                                │
# │     - **Description:** Conduct a final review meeting and make necessary adjustments before official site       │
# │  launch.                                                                                                        │
# │     - **Timeline:** 1 week                                                                                      │
# │     - **Dependencies:** Task 12                                                                                 │
# │     - **Deliverables:** Launched website                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Gantt Chart Visualization                                                                                  │
# │                                                                                                                 │
# │  ```plaintext                                                                                                   │
# │  | Task                                   | Week 1  | Week 2  | Week 3  | Week 4  | Week 5  | Week 6  | Week 7  │
# │  | Week 8  | Week 9  | Week 10 |                                                                                │
# │  |----------------------------------------|---------|---------|---------|---------|---------|---------|-------  │
# │  --|---------|---------|----------|                                                                             │
# │  | 1. Project Kickoff                    |                                                                      │
# │  X-------|---------|---------|---------|---------|---------|---------|---------|---------|----------|           │
# │  | 2. Create Responsive Design            |         | X-------|---------|---------|         |         |         │
# │  |         |         |          |                                                                               │
# │  | 3. Develop User Interface (UI)        |         |         | X-------|---------|         |         |          │
# │  |         |         |          |                                                                               │
# │  | 4. User-Friendly Navigation System     |         |         |         | X-------|         |         |         │
# │  |         |         |          |                                                                               │
# │  | 5. Develop “About Us” Page            |         |         |         | X-------|         |         |          │
# │  |         |         |          |                                                                               │
# │  | 6. Create “Services” Page             |         |         |         | X-------|         |         |          │
# │  |         |         |          |                                                                               │
# │  | 7. Implement “Contact Us” Page        |         |         |         | X-------|         |         |          │
# │  |         |         |          |                                                                               │
# │  | 8. Develop Blog Section                |         |         |         |         | X-------| X-------|         │
# │  |         |         |          |                                                                               │
# │  | 9. Optimize Performance and SEO        |         |         |         |         |         |         |         │
# │  X-------|         |         |          |                                                                       │
# │  | 10. Integrate Social Media Links       |         |         |         |         |         |         |         │
# │  X-------|         |         |          |                                                                       │
# │  | 11. Create Testimonials Section        |         |         |         |         |         |         |         │
# │  X-------|         |         |          |                                                                       │
# │  | 12. Quality Assurance Testing           |         |         |         |         |         |         |        │
# │  | X-------| X-------|          |                                                                               │
# │  | 13. Final Review and Launch            |         |         |         |         |         |         |         │
# │  |         |         | X--------|                                                                               │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Summary                                                                                                    │
# │  This comprehensive plan outlines each task required for creating a website for a small business, detailing     │
# │  the scope, timelines, and dependencies to ensure successful delivery of the project. Stakeholders will         │
# │  receive regular updates and deliverables at the end of each phase, culminating in a launched website designed  │
# │  to enhance the business's online presence.                                                                     │
# │                                                                                                                 │
# │  **End of Plan.**                                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: d827d471-14e8-4a32-a0fb-88dfe687b008                                                                     │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Detailed Estimation Report for Website Project                                                             │
# │                                                                                                                 │
# │  **Project Title:** Create a Website for a Small Business                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Task Breakdown and Estimation                                                                              │
# │                                                                                                                 │
# │  1. **Project Kickoff and Requirements Gathering**                                                              │
# │     - **Estimated Time:** 1 week                                                                                │
# │     - **Resources Required:** 1 Project Manager, 1 Software Engineer, 1 Designer                                │
# │     - **Effort:** 40 hours                                                                                      │
# │     - **Risks/Uncertainties:** Potential for incomplete requirements if stakeholders are unavailable.           │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - Project charter, requirements document                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  2. **Create Responsive Design**                                                                                │
# │     - **Estimated Time:** 2 weeks                                                                               │
# │     - **Resources Required:** 1 Designer                                                                        │
# │     - **Effort:** 80 hours                                                                                      │
# │     - **Risks/Uncertainties:** Design iterations may extend the timeline if not properly approved on the first  │
# │  try.                                                                                                           │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - Wireframes, mockups                                                                                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  3. **Develop User Interface (UI)**                                                                             │
# │     - **Estimated Time:** 3 weeks                                                                               │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 120 hours                                                                                     │
# │     - **Risks/Uncertainties:** Integration challenges with existing components; potential need for refactoring  │
# │  code may arise.                                                                                                │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - Fully coded UI components                                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  4. **Create User-Friendly Navigation System**                                                                  │
# │     - **Estimated Time:** 1 week                                                                                │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours                                                                                      │
# │     - **Risks/Uncertainties:** Overcomplicating navigation could confuse users—simplicity is key.               │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - Functional navigation system                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  5. **Develop “About Us” Page**                                                                                 │
# │     - **Estimated Time:** 1 week                                                                                │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours                                                                                      │
# │     - **Risks/Uncertainties:** Delays in content gathering from stakeholders may hamper progress.               │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - “About Us” page                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  6. **Create “Services” Page**                                                                                  │
# │     - **Estimated Time:** 1 week                                                                                │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours                                                                                      │
# │     - **Risks/Uncertainties:** Similar content gathering dependencies as Task 5 may apply.                      │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - “Services” page                                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  7. **Implement “Contact Us” Page**                                                                             │
# │     - **Estimated Time:** 1 week                                                                                │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours                                                                                      │
# │     - **Risks/Uncertainties:** Technical challenges could arise during integration with email services.         │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - “Contact Us” page                                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  8. **Develop Blog Section**                                                                                    │
# │     - **Estimated Time:** 2 weeks                                                                               │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 80 hours                                                                                      │
# │     - **Risks/Uncertainties:** User interface may require adjustments if feedback from testers is critical.     │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - Blog section                                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  9. **Optimize Performance and SEO**                                                                            │
# │     - **Estimated Time:** 1 week                                                                                │
# │     - **Resources Required:** 1 Software Engineer                                                               │
# │     - **Effort:** 40 hours                                                                                      │
# │     - **Risks/Uncertainties:** Performance optimization may reveal deeper issues needing more extensive fixes.  │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │     - Performance optimization report                                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  10. **Integrate Social Media Links**                                                                           │
# │      - **Estimated Time:** 1 week                                                                               │
# │      - **Resources Required:** 1 Software Engineer                                                              │
# │      - **Effort:** 40 hours                                                                                     │
# │      - **Risks/Uncertainties:** Social media platform changes can impact integration approach.                  │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │      - Social media integration                                                                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  11. **Create Testimonials Section**                                                                            │
# │      - **Estimated Time:** 1 week                                                                               │
# │      - **Resources Required:** 1 Software Engineer                                                              │
# │      - **Effort:** 40 hours                                                                                     │
# │      - **Risks/Uncertainties:** Gathering testimonials might lead to delays if clients are unresponsive.        │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │      - Testimonials page                                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  12. **Quality Assurance Testing**                                                                              │
# │      - **Estimated Time:** 2 weeks                                                                              │
# │      - **Resources Required:** 2 QA Engineers                                                                   │
# │      - **Effort:** 160 hours                                                                                    │
# │      - **Risks/Uncertainties:** Overlooking minor bugs might lead to larger issues post-launch; thoroughness    │
# │  is essential.                                                                                                  │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │      - QA report, list of identified issues                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  13. **Final Review and Launch**                                                                                │
# │      - **Estimated Time:** 1 week                                                                               │
# │      - **Resources Required:** 1 Project Manager, 1 Software Engineer                                           │
# │      - **Effort:** 40 hours                                                                                     │
# │      - **Risks/Uncertainties:** Last-minute changes may arise; time must be allocated for these revisions.      │
# │                                                                                                                 │
# │  **Deliverables:**                                                                                              │
# │      - Launched website                                                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# ...
# │  development tasks, leveraging her engineering skills for UI and content page creation, while Alice Johnson     │
# │  and Tom Brown, the QA Engineers, collaborate to ensure quality assurance with shared loads. This distribution  │
# │  ensures project milestones are achievable while minimizing the risk of overburdening any individual.           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 017eed03-53f2-43ff-a4eb-7162811ac124                                                                     │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: edaa4290-bf93-413c-b978-dd16c6dd21fc                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: {                                                                                                │
# │    "tasks": [                                                                                                   │
# │      {                                                                                                          │
# │        "task_name": "Project Kickoff and Requirements Gathering",                                               │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["John Doe", "Jane Doe", "Bob Smith"]                                              │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create Responsive Design",                                                                 │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith"]                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop User Interface (UI)",                                                              │
# │        "estimated_time_hours": 120,                                                                             │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create User-Friendly Navigation System",                                                   │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop “About Us” Page",                                                                  │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create “Services” Page",                                                                   │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement “Contact Us” Page",                                                              │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop Blog Section",                                                                     │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Optimize Performance and SEO",                                                             │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Integrate Social Media Links",                                                             │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create Testimonials Section",                                                              │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Quality Assurance Testing",                                                                │
# │        "estimated_time_hours": 160,                                                                             │
# │        "required_resources": ["Alice Johnson", "Tom Brown"]                                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Final Review and Launch",                                                                  │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["John Doe", "Jane Doe"]                                                           │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "milestones": [                                                                                              │
# │      {                                                                                                          │
# │        "milestone_name": "Project Kickoff Completed",                                                           │
# │        "tasks": ["Project Kickoff and Requirements Gathering"]                                                  │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Design Phase Completed",                                                              │
# │        "tasks": [                                                                                               │
# │          "Create Responsive Design",                                                                            │
# │          "Develop User Interface (UI)"                                                                          │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Content Development Completed",                                                       │
# │        "tasks": [                                                                                               │
# │          "Create User-Friendly Navigation System",                                                              │
# │          "Develop “About Us” Page",                                                                             │
# │          "Create “Services” Page",                                                                              │
# │          "Implement “Contact Us” Page",                                                                         │
# │          "Develop Blog Section",                                                                                │
# │          "Create Testimonials Section"                                                                          │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Testing Phase Completed",                                                             │
# │        "tasks": ["Quality Assurance Testing"]                                                                   │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Project Launched",                                                                    │
# │        "tasks": ["Final Review and Launch"]                                                                     │
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  Summary: The tasks for the Website project have been strategically allocated based on the skills and roles of  │
# │  team members to maximize efficiency and ensure even workload distribution. John Doe, the Project Manager,      │
# │  spearheads initial project activities and final reviews. Bob Smith, the Designer, is assigned design-related   │
# │  tasks alone to maintain focus and output quality. Jane Doe, the Software Engineer, handles the bulk of         │
# │  development tasks, leveraging her engineering skills for UI and content page creation, while Alice Johnson     │
# │  and Tom Brown, the QA Engineers, collaborate to ensure quality assurance with shared loads. This distribution  │
# │  ensures project milestones are achievable while minimizing the risk of overburdening any individual.           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0013
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          8884           5393                     0               3491
#
#    successful_requests
# 0                    3

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kickoff and Requirements Gathering',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe', 'Jane Doe', 'Bob Smith']},
#   {'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop User Interface (UI)',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create User-Friendly Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop “About Us” Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create “Services” Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement “Contact Us” Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize Performance and SEO',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 160.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Review and Launch',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe', 'Jane Doe']}],
#  'milestones': [{'milestone_name': 'Project Kickoff Completed',
#    'tasks': ['Project Kickoff and Requirements Gathering']},
#   {'milestone_name': 'Design Phase Completed',
#    'tasks': ['Create Responsive Design', 'Develop User Interface (UI)']},
#   {'milestone_name': 'Content Development Completed',
#    'tasks': ['Create User-Friendly Navigation System',
#     'Develop “About Us” Page',
#     'Create “Services” Page',
#     'Implement “Contact Us” Page',
#     'Develop Blog Section',
#     'Create Testimonials Section']},
#   {'milestone_name': 'Testing Phase Completed',
#    'tasks': ['Quality Assurance Testing']},
#   {'milestone_name': 'Project Launched',
#    'tasks': ['Final Review and Launch']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_e0d92 th {
#   font-size: 120%;
# }
# #T_e0d92  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_e0d92" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0d92_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_e0d92_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_e0d92_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0d92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0d92_row0_col0" class="data row0 col0" >Project Kickoff and Requirements Gathering</td>
#       <td id="T_e0d92_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_e0d92_row0_col2" class="data row0 col2" >['John Doe', 'Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0d92_row1_col0" class="data row1 col0" >Create Responsive Design</td>
#       <td id="T_e0d92_row1_col1" class="data row1 col1" >80.000000</td>
#       <td id="T_e0d92_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0d92_row2_col0" class="data row2 col0" >Develop User Interface (UI)</td>
#       <td id="T_e0d92_row2_col1" class="data row2 col1" >120.000000</td>
#       <td id="T_e0d92_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0d92_row3_col0" class="data row3 col0" >Create User-Friendly Navigation System</td>
#       <td id="T_e0d92_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_e0d92_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0d92_row4_col0" class="data row4 col0" >Develop “About Us” Page</td>
#       <td id="T_e0d92_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_e0d92_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0d92_row5_col0" class="data row5 col0" >Create “Services” Page</td>
#       <td id="T_e0d92_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_e0d92_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0d92_row6_col0" class="data row6 col0" >Implement “Contact Us” Page</td>
#       <td id="T_e0d92_row6_col1" class="data row6 col1" >40.000000</td>
#       <td id="T_e0d92_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e0d92_row7_col0" class="data row7 col0" >Develop Blog Section</td>
#       <td id="T_e0d92_row7_col1" class="data row7 col1" >80.000000</td>
#       <td id="T_e0d92_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e0d92_row8_col0" class="data row8 col0" >Optimize Performance and SEO</td>
#       <td id="T_e0d92_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_e0d92_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e0d92_row9_col0" class="data row9 col0" >Integrate Social Media Links</td>
#       <td id="T_e0d92_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_e0d92_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e0d92_row10_col0" class="data row10 col0" >Create Testimonials Section</td>
#       <td id="T_e0d92_row10_col1" class="data row10 col1" >40.000000</td>
#       <td id="T_e0d92_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e0d92_row11_col0" class="data row11 col0" >Quality Assurance Testing</td>
#       <td id="T_e0d92_row11_col1" class="data row11 col1" >160.000000</td>
#       <td id="T_e0d92_row11_col2" class="data row11 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_e0d92_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e0d92_row12_col0" class="data row12 col0" >Final Review and Launch</td>
#       <td id="T_e0d92_row12_col1" class="data row12 col1" >40.000000</td>
#       <td id="T_e0d92_row12_col2" class="data row12 col2" >['John Doe', 'Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_24d56 th {
#   font-size: 120%;
# }
# #T_24d56  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_24d56" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24d56_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_24d56_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24d56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24d56_row0_col0" class="data row0 col0" >Project Kickoff Completed</td>
#       <td id="T_24d56_row0_col1" class="data row0 col1" >['Project Kickoff and Requirements Gathering']</td>
#     </tr>
#     <tr>
#       <th id="T_24d56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24d56_row1_col0" class="data row1 col0" >Design Phase Completed</td>
#       <td id="T_24d56_row1_col1" class="data row1 col1" >['Create Responsive Design', 'Develop User Interface (UI)']</td>
#     </tr>
#     <tr>
#       <th id="T_24d56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_24d56_row2_col0" class="data row2 col0" >Content Development Completed</td>
#       <td id="T_24d56_row2_col1" class="data row2 col1" >['Create User-Friendly Navigation System', 'Develop “About Us” Page', 'Create “Services” Page', 'Implement “Contact Us” Page', 'Develop Blog Section', 'Create Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_24d56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_24d56_row3_col0" class="data row3 col0" >Testing Phase Completed</td>
#       <td id="T_24d56_row3_col1" class="data row3 col1" >['Quality Assurance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_24d56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_24d56_row4_col0" class="data row4 col0" >Project Launched</td>
#       <td id="T_24d56_row4_col1" class="data row4 col1" >['Final Review and Launch']</td>
#     </tr>
#   </tbody>
# </table>
